# %%
# !which python
# !which jupyter-lab
# Out:
# /Users/Aleksei_Kornev2/physics/Faddeev/project/venv/bin/python
# /Users/Aleksei_Kornev2/physics/Faddeev/project/venv/bin/jupyter-lab

# %%
import sympy as sym


# Not necessary but gives nice-looking latex output
# More info at: http://docs.sympy.org/latest/tutorial/printing.html
sym.init_printing()

t = sym.symbols('t')
m1, m2, m3 = sym.symbols('m_alpha m_beta m_gamma', positive=True)
xa, ya, xb, yb = sym.symbols('x_alpha y_alpha x_beta y_beta')
alpha, beta = sym.symbols('alpha beta')
cab = -sym.sqrt(m1 * m2 / (m1 + m3) / (m2 + m3))
sab = (-1)**(beta - alpha) * (beta - alpha)/sym.Abs(beta-alpha) * sym.sqrt(1 - cab**2)
rot = sym.Matrix([[cab, sab],[-sab, cab]])
rot.applyfunc(sym.factor)
# Out:
# ⎡                ________   ____                      -α + β   ____
# ⎢             -╲╱ mₐₗₚₕₐ ⋅╲╱ mᵦ                  -(-1)      ⋅╲╱ mᵧ ⋅(α - β)⋅╲╱
# ⎢         ───────────────────────────            ─────────────────────────────
# ⎢           _____________   _________                    _____________   _____
# ⎢         ╲╱ mₐₗₚₕₐ + mᵧ ⋅╲╱ mᵦ + mᵧ                   ╲╱ mₐₗₚₕₐ + mᵧ ⋅╲╱ mᵦ +
# ⎢
# ⎢    -α + β   ____           __________________                   ________   _
# ⎢(-1)      ⋅╲╱ mᵧ ⋅(α - β)⋅╲╱ mₐₗₚₕₐ + mᵦ + mᵧ                 -╲╱ mₐₗₚₕₐ ⋅╲╱
# ⎢──────────────────────────────────────────────            ───────────────────
# ⎢       _____________   _________                            _____________   _
# ⎣     ╲╱ mₐₗₚₕₐ + mᵧ ⋅╲╱ mᵦ + mᵧ ⋅│α - β│                  ╲╱ mₐₗₚₕₐ + mᵧ ⋅╲╱
#
# __________________ ⎤
#  mₐₗₚₕₐ + mᵦ + mᵧ  ⎥
# ───────────────────⎥
# ____               ⎥
#  mᵧ ⋅│α - β│       ⎥
#                    ⎥
# ___                ⎥
# mᵦ                 ⎥
# ────────           ⎥
# ________           ⎥
# mᵦ + mᵧ            ⎦

# %%
(rot @ rot.transpose()).subs({"alpha": 0, "beta": 1})
# Out:
# ⎡1  0⎤
# ⎢    ⎥
# ⎣0  1⎦

# %%
(rot.transpose() @ rot).subs({"alpha": 0, "beta": 1})
# Out:
# ⎡1  0⎤
# ⎢    ⎥
# ⎣0  1⎦

# %%
rot.simplify()
det = rot.det()
#det.factor()
my_det = cab**2 + sab**2
my_det.simplify()
bla = sab**2 + cab**2
bla.powsimp()
# Out:
#     -2⋅α + 2⋅β         2 ⎛         mₐₗₚₕₐ⋅mᵦ           ⎞
# (-1)          ⋅(-α + β) ⋅⎜- ─────────────────────── + 1⎟
#                          ⎝  (mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)    ⎠          mₐₗₚₕₐ⋅mᵦ
# ──────────────────────────────────────────────────────── + ───────────────────
#                                2                           (mₐₗₚₕₐ + mᵧ)⋅(mᵦ +
#                         │α - β│
#
#
#
#
# ────
#  mᵧ)

# %%
ga = sym.sqrt(2 * m2 * m3/ (m2 + m3))
gb = sym.sqrt(2 * m1 * (m2 + m3)/ (m1 + m2 + m3))
g = sym.Matrix([[ga, 0], [0, gb]])

# m1 = 1836
# m2 = 1836
# m3 = 1
# import numpy as np
# print(2 * m2 * m3 / (m2 + m3))
# print(2 * m1 * (m2 + m3)/ (m1 + m2 + m3))
ha = sym.sqrt(2 * m3 * m1/ (m3 + m1))
hb = sym.sqrt(2 * m2 * (m3 + m1)/ (m1 + m2 + m3))
h = sym.Matrix([[ha, 0], [0, hb]])

scaled_rot = g.inv() @ rot @ h
scaled_rot[1, 1].factor()
# h.inv() @ rot.inv() @ g
#from_beta_to_alpha.subs({"m_alpha": 1836.0, "m_beta": 1836, "m_gamma": 1.0})
# Out:
#   -mᵦ
# ───────
# mᵦ + mᵧ

# %%
a = ((scaled_rot.transpose() @ scaled_rot).subs({"alpha": 1, "beta": 0})).transpose()

# %%
a
# Out:
# ⎡
# ⎢                                               ⎛         mₐₗₚₕₐ⋅mᵦ
# ⎢                                    2       mᵧ⋅⎜- ─────────────────────── + 1
# ⎢                              mₐₗₚₕₐ           ⎝  (mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)
# ⎢                           ────────────── + ─────────────────────────────────
# ⎢                                        2                  (mₐₗₚₕₐ + mᵧ)⋅(mᵦ
# ⎢                           (mₐₗₚₕₐ + mᵧ)
# ⎢
# ⎢                         _______________________________                 ____
# ⎢           _________    ╱          mₐₗₚₕₐ⋅mᵦ                    ____    ╱
# ⎢  mₐₗₚₕₐ⋅╲╱ mᵦ + mᵧ ⋅  ╱  - ─────────────────────── + 1    mᵦ⋅╲╱ mᵧ ⋅  ╱  - ─
# ⎢                     ╲╱     (mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)                  ╲╱     (
# ⎢- ────────────────────────────────────────────────────── + ──────────────────
# ⎢         ____   _____________   __________________
# ⎣       ╲╱ mᵧ ⋅╲╱ mₐₗₚₕₐ + mᵧ ⋅╲╱ mₐₗₚₕₐ + mᵦ + mᵧ
#
#                                                                            ___
# ⎞                                                            _________    ╱
# ⎟⋅(mₐₗₚₕₐ + mᵦ + mᵧ)                                mₐₗₚₕₐ⋅╲╱ mᵦ + mᵧ ⋅  ╱  -
# ⎠                                                                      ╲╱
# ────────────────────                              - ──────────────────────────
# + mᵧ)                                                      ____   ____________
#                                                          ╲╱ mᵧ ⋅╲╱ mₐₗₚₕₐ + mᵧ
#
# ___________________________
#       mₐₗₚₕₐ⋅mᵦ               __________________
# ────────────────────── + 1 ⋅╲╱ mₐₗₚₕₐ + mᵦ + mᵧ
# mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)
# ────────────────────────────────────────────────
#    _____________          3/2
#  ╲╱ mₐₗₚₕₐ + mᵧ ⋅(mᵦ + mᵧ)
#
# ____________________________                 _______________________________
#        mₐₗₚₕₐ⋅mᵦ                    ____    ╱          mₐₗₚₕₐ⋅mᵦ
# ─────────────────────── + 1    mᵦ⋅╲╱ mᵧ ⋅  ╱  - ─────────────────────── + 1 ⋅╲
# (mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)                  ╲╱     (mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)
# ──────────────────────────── + ───────────────────────────────────────────────
# _   __________________                              _____________          3/2
#  ⋅╲╱ mₐₗₚₕₐ + mᵦ + mᵧ                             ╲╱ mₐₗₚₕₐ + mᵧ ⋅(mᵦ + mᵧ)
#
#
#                                      ⎛         mₐₗₚₕₐ⋅mᵦ           ⎞
#      2       (mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)⋅⎜- ─────────────────────── + 1⎟
#    mᵦ                                ⎝  (mₐₗₚₕₐ + mᵧ)⋅(mᵦ + mᵧ)    ⎠
# ────────── + ───────────────────────────────────────────────────────
#          2                    mᵧ⋅(mₐₗₚₕₐ + mᵦ + mᵧ)
# (mᵦ + mᵧ)
#
#                    ⎤
#  __________________⎥
# ╱ mₐₗₚₕₐ + mᵦ + mᵧ ⎥
#                    ⎥
# ───────────────────⎥
#                    ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#                    ⎥
#                    ⎦

# %%
inv = sym.simplify(matrix.inv()).applyfunc(sym.factor)
inv
# Out:
# ⎡                                                        2      ⎤
# ⎢   m₂        m₃⋅(m₁ + m₂ + m₃)            (m₁ + m₂ + m₃)       ⎥
# ⎢───────  ──────────────────────────  ──────────────────────────⎥
# ⎢m₁ + m₂  (m₁ + m₂)⋅(m₁ + m₂ + 2⋅m₃)  (m₁ + m₂)⋅(m₁ + m₂ + 2⋅m₃)⎥
# ⎢                                                               ⎥
# ⎢                                                        2      ⎥
# ⎢  -m₁        m₃⋅(m₁ + m₂ + m₃)            (m₁ + m₂ + m₃)       ⎥
# ⎢───────  ──────────────────────────  ──────────────────────────⎥
# ⎢m₁ + m₂  (m₁ + m₂)⋅(m₁ + m₂ + 2⋅m₃)  (m₁ + m₂)⋅(m₁ + m₂ + 2⋅m₃)⎥
# ⎢                                                               ⎥
# ⎢              -(m₁ + m₂ + m₃)               m₁ + m₂ + m₃       ⎥
# ⎢   0          ────────────────             ──────────────      ⎥
# ⎣               m₁ + m₂ + 2⋅m₃              m₁ + m₂ + 2⋅m₃      ⎦

# %%
vec_old = inv @ vec_new
vec_old = vec_old.diff(t)
vec_old = vec_old.applyfunc(lambda x:x**2)
for i in range(3):
    vec_old[i] *= 1/coefs[i]
vec_old.applyfunc(sym.factor)
#vec_old
# Out:
# ⎡
# ⎢⎛    2 d                  d                d                d
# ⎢⎜- m₁ ⋅──(φ(t)) - 2⋅m₁⋅m₂⋅──(φ(t)) - m₁⋅m₂⋅──(ψ(t)) + m₁⋅m₃⋅──(χ(t)) - 2⋅m₁⋅m
# ⎢⎝      dt                 dt               dt               dt
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢⎛    2 d            2 d                  d                d                d
# ⎢⎜- m₁ ⋅──(φ(t)) + m₁ ⋅──(ψ(t)) - 2⋅m₁⋅m₂⋅──(φ(t)) + m₁⋅m₂⋅──(ψ(t)) + m₁⋅m₃⋅──
# ⎢⎝      dt             dt                 dt               dt               dt
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#
#   d            2 d            2 d                d                  d
# ₃⋅──(φ(t)) - m₂ ⋅──(φ(t)) - m₂ ⋅──(ψ(t)) + m₂⋅m₃⋅──(χ(t)) - 2⋅m₂⋅m₃⋅──(φ(t)) -
#   dt             dt             dt               dt                 dt
# ──────────────────────────────────────────────────────────────────────────────
#                       2                 2
#         2⋅m₁⋅(m₁ + m₂) ⋅(m₁ + m₂ + 2⋅m₃)
#
#
#                  d                  d            2 d                d
# (χ(t)) - 2⋅m₁⋅m₃⋅──(φ(t)) + 2⋅m₁⋅m₃⋅──(ψ(t)) - m₂ ⋅──(φ(t)) + m₂⋅m₃⋅──(χ(t)) -
#                  dt                 dt             dt               dt
# ──────────────────────────────────────────────────────────────────────────────
#                       2                 2
#         2⋅m₂⋅(m₁ + m₂) ⋅(m₁ + m₂ + 2⋅m₃)
#
#                            2
#       ⎛d          d       ⎞                2
#       ⎜──(χ(t)) + ──(φ(t))⎟ ⋅(m₁ + m₂ + m₃)
#       ⎝dt         dt      ⎠
#       ──────────────────────────────────────
#                                    2
#               2⋅m₃⋅(m₁ + m₂ + 2⋅m₃)
#
#                                                 2⎤
#          d            2 d            2 d       ⎞ ⎥
#  2⋅m₂⋅m₃⋅──(ψ(t)) + m₃ ⋅──(χ(t)) - m₃ ⋅──(φ(t))⎟ ⎥
#          dt             dt             dt      ⎠ ⎥
# ─────────────────────────────────────────────────⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                 2⎥
#          d            2 d            2 d       ⎞ ⎥
#  2⋅m₂⋅m₃⋅──(φ(t)) + m₃ ⋅──(χ(t)) - m₃ ⋅──(φ(t))⎟ ⎥
#          dt             dt             dt      ⎠ ⎥
# ─────────────────────────────────────────────────⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎥
#                                                  ⎦

# %%
vec_old.elementary_coefs
# Out:
#   File "/var/folders/9j/rj279c8x09zfknrp0x7xqkz40000gp/T/ipykernel_17864/204500598.py", line 1
#     vec_old ./ coefs
#              ^
# SyntaxError: invalid syntax
